# %% [markdown]
# # Análisis exploratorio de datos tabulados

# %%
import pandas as pd

# %%
# Lectura de los datos
df = pd.read_csv('Human_Resources.csv')
df.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0              1  ...                         1             80
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.tail(2)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 1468                2              9                   6
# ...

# %%
# Configurar a pandas para que me muestre todas las columnas que tengo
pd.set_option('display.max_columns',None)

# %%
df.head(3)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0              1             1.0                        2  Female          94
# 1              1             2.0                        3    Male          61
# 2              1             4.0                        4    Male          92
#
#    JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   MonthlyIncome             1467 non-null   float64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1469 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1469 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EmployeeNumber            1469 non-null   float64
#  11  EnvironmentSatisfaction   1470 non-null   int64
#  12  Gender                    1469 non-null   object
# ...

# %%
# Identificación de valores únicos
df['DistanceFromHome'].unique()
# Out:
# array([ 1,  8,  2,  3, 24, 23, 27, 16, 15, 26, 19, 21,  5, 11,  9,  7,  6,
#        10,  4, 25, 12, 18, 29, 22, 14, 20, 28, 17, 13])

# %%
df.nunique()
# Out:
# Age                           43
# MonthlyIncome               1346
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1469
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyRate                 1425
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
# Genra una lista de los nombres de las columnas en la tabla
df.columns.to_list()
# Out:
# ['Age',
#  'MonthlyIncome',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
for name in df.columns.to_list():
    print(f'La columna: {name} contiene los elementos {df[name].unique()}')
# Out:
# La columna: Age contiene los elementos [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# La columna: MonthlyIncome contiene los elementos [5993.   nan 2090. ... 9991. 5390. 4404.]
# La columna: Attrition contiene los elementos ['Yes' 'No']
# La columna: BusinessTravel contiene los elementos ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# La columna: DailyRate contiene los elementos [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
# ...

# %%
# Eliminar columnas que no brindan información
valores_unicos_n = df.nunique()

columnas_sin_info = valores_unicos_n[valores_unicos_n==1].index.tolist()
columnas_sin_info
# Out:
# ['EmployeeCount', 'Over18', 'StandardHours']

# %%
df_clean=df.drop(columnas_sin_info, axis=1)

# %%
df_clean.head(3)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
#
#    EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0             1.0                        2  Female          94
# 1             2.0                        3    Male          61
# 2             4.0                        4    Male          92
#
#    JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0               3         2        Sales Executive                4
# ...

# %%
# Eliminar una columna en especifico
df_clean = df_clean.drop('JobSatisfaction',axis=1)

# %%
df_clean.head(3)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
#
#    EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0             1.0                        2  Female          94
# 1             2.0                        3    Male          61
# 2             4.0                        4    Male          92
#
#    JobInvolvement  JobLevel                JobRole MaritalStatus  MonthlyRate  \
# 0               3         2        Sales Executive        Single      19479.0
# ...

# %%
df_clean.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1470.000000    1467.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810    6505.155419   802.485714          9.192517     2.912925
# std       9.135373    4711.297846   403.509100          8.106864     1.024165
# min      18.000000    1009.000000   102.000000          1.000000     1.000000
# 25%      30.000000    2911.000000   465.000000          2.000000     2.000000
# 50%      36.000000    4908.000000   802.000000          7.000000     3.000000
# 75%      43.000000    8378.000000  1157.000000         14.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1469.000000              1470.000000  1470.000000     1470.000000
# mean      1025.556161                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ## División de un dataset

# %%
siguen_trabajando = df_clean[df_clean['Attrition'] == 'No']
renunciaron = df_clean[df_clean['Attrition'] == 'Yes']

# %%
siguen_trabajando['Attrition'].unique()
# Out:
# array(['No'], dtype=object)

# %%
renunciaron.describe()
# Out:
#               Age  MonthlyIncome    DailyRate  DistanceFromHome   Education  \
# count  237.000000     236.000000   237.000000        237.000000  237.000000
# mean    33.607595    4771.588983   750.362869         10.632911    2.839662
# std      9.689350    3640.097444   401.899519          8.452525    1.008244
# min     18.000000    1009.000000   103.000000          1.000000    1.000000
# 25%     28.000000    2371.500000   408.000000          3.000000    2.000000
# 50%     32.000000    3187.000000   699.000000          9.000000    3.000000
# 75%     39.000000    5850.000000  1092.000000         17.000000    4.000000
# max     58.000000   19859.000000  1496.000000         29.000000    5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count      237.000000               237.000000  237.000000      237.000000
# mean      1010.345992                 2.464135   65.573840        2.518987
# ...

# %%
siguen_trabajando.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1233.000000    1231.000000  1233.000000       1233.000000  1233.000000
# mean     37.561233    6837.504468   812.504461          8.915653     2.927007
# std       8.888360    4820.415800   403.208379          8.012633     1.027002
# min      18.000000    1051.000000   102.000000          1.000000     1.000000
# 25%      31.000000    3211.500000   477.000000          2.000000     2.000000
# 50%      36.000000    5206.000000   817.000000          7.000000     3.000000
# 75%      43.000000    8835.500000  1176.000000         13.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1232.000000              1233.000000  1233.000000     1233.000000
# mean      1028.482143                 2.771290    65.952149        2.770479
# ...

# %%
# Cuando se usa pandas en lugar de utilizar and y or se usan & y |
personas_sueldo_bien = siguen_trabajando[(siguen_trabajando['MonthlyIncome'] > 15000) & (siguen_trabajando['DistanceFromHome'] > 8)
                                         & (siguen_trabajando['EnvironmentSatisfaction'] == 4)]
personas_sueldo_bien.head()
# Out:
#      Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 112   54        17328.0        No         Non-Travel        142
# 147   41        17181.0        No  Travel_Frequently        857
# 235   43        16064.0        No      Travel_Rarely       1034
# 473   49        19502.0        No      Travel_Rarely       1245
# 710   33        17444.0        No         Non-Travel        722
#
#                  Department  DistanceFromHome  Education   EducationField  \
# 112         Human Resources                26          3  Human Resources
# 147  Research & Development                10          3    Life Sciences
# 235                   Sales                16          3        Marketing
# 473  Research & Development                18          4    Life Sciences
# 710                   Sales                17          3    Life Sciences
#
#      EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 112           148.0                        4  Female          30
# ...

# %%
personas_sueldo_bien.describe()
# Out:
#              Age  MonthlyIncome    DailyRate  DistanceFromHome  Education  \
# count  17.000000      17.000000    17.000000         17.000000  17.000000
# mean   46.058824   18083.823529   804.117647         17.823529   2.882353
# std     5.814536    1337.367341   484.367614          7.443414   0.600245
# min    33.000000   16064.000000   105.000000          9.000000   2.000000
# 25%    43.000000   17174.000000   237.000000         10.000000   3.000000
# 50%    46.000000   17650.000000  1005.000000         17.000000   3.000000
# 75%    49.000000   19502.000000  1224.000000         26.000000   3.000000
# max    58.000000   19847.000000  1450.000000         28.000000   4.000000
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count       17.000000                     17.0   17.000000       17.000000
# mean      1256.117647                      4.0   67.294118        2.764706
# std        616.780439                      0.0   23.618755        0.562296
# ...

# %%
personas_sueldo_bien['JobRole'].unique()
# Out:
# array(['Manager', 'Research Director'], dtype=object)

# %%
personas_sueldo_bien[personas_sueldo_bien['JobRole'] == 'Manager'].describe()
# Out:
#              Age  MonthlyIncome    DailyRate  DistanceFromHome  Education  \
# count  11.000000      11.000000    11.000000         11.000000  11.000000
# mean   45.545455   18115.000000   662.545455         16.000000   2.909091
# std     7.104416    1290.906891   446.154987          6.855655   0.539360
# min    33.000000   16064.000000   105.000000          9.000000   2.000000
# 25%    41.500000   17254.500000   189.500000          9.500000   3.000000
# 50%    45.000000   17650.000000   722.000000         16.000000   3.000000
# 75%    49.500000   19522.000000  1046.500000         21.500000   3.000000
# max    58.000000   19847.000000  1234.000000         26.000000   4.000000
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count       11.000000                     11.0   11.000000       11.000000
# mean      1188.454545                      4.0   74.545455        2.909091
# std        706.424711                      0.0   22.927554        0.539360
# ...

# %% [markdown]
# Agregar resumen de lo analizado.

# %% [markdown]
# ## Tratamiento de datos faltantes

# %%
# Contamos lo svalores nulos por variable
valores_nulos = df_clean.isnull().sum()

# %%
len(df_clean)
# Out:
# 1470

# %%
porcentaje = (valores_nulos/len(df_clean)*100)
porcentaje
# Out:
# Age                         0.000000
# MonthlyIncome               0.204082
# Attrition                   0.000000
# BusinessTravel              0.000000
# DailyRate                   0.000000
# Department                  0.068027
# DistanceFromHome            0.000000
# Education                   0.000000
# EducationField              0.068027
# EmployeeNumber              0.068027
# EnvironmentSatisfaction     0.000000
# Gender                      0.068027
# HourlyRate                  0.000000
# JobInvolvement              0.000000
# JobLevel                    0.000000
# JobRole                     0.068027
# MaritalStatus               0.068027
# MonthlyRate                 0.136054
# NumCompaniesWorked          0.000000
# OverTime                    0.000000
# PercentSalaryHike           0.068027
# PerformanceRating           0.068027
# RelationshipSatisfaction    0.000000
# StockOptionLevel            0.000000
# TotalWorkingYears           0.000000
# ...

# %%
df_clean_sn_na = df_clean.dropna(axis=0) # axis = 0 indica que quiero eliminar las filas, axis = 1 indica las columnas
#df_clean_sn_na = df_clean.dropna(axis=1)
#df_clean_sn_na = df_clean.dropna(subset=['MonthlyIncome','Department'])
#df_clean['MonthlyIncome'] = df_clean['MonthlyIncome'].fillna(df_clean['MonthlyIncome'].mean())

# %%
#len(df_clean_sn_na)

# %%
#df_clean_sn_na.isnull().sum()

# %%
#%pip install -U scikit-learn

# %%
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer

# %%
# Imputación para datos númericos
impute_numeric = SimpleImputer(strategy='mean')
numeric_columns = df_clean.select_dtypes(include='number').columns
numeric_columns
# Out:
# Index(['Age', 'MonthlyIncome', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df_clean[numeric_columns] = impute_numeric.fit_transform(df_clean[numeric_columns])

# %%
# Imputación para datos categoricos
impute_categorico = SimpleImputer(strategy='most_frequent')
categorical_columns = df_clean.select_dtypes(include='object').columns
categorical_columns
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'OverTime'],
#       dtype='object')

# %%
df_clean[categorical_columns] = impute_categorico.fit_transform(df_clean[categorical_columns])

# %%
df_clean.isnull().sum()
# Out:
# Age                         0
# MonthlyIncome               0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# ...

# %%
df_clean['Department']
# Out:
# 0                        Sales
# 1       Research & Development
# 2       Research & Development
# 3       Research & Development
# 4       Research & Development
#                  ...
# 1465    Research & Development
# 1466    Research & Development
# 1467    Research & Development
# 1468                     Sales
# 1469    Research & Development
# Name: Department, Length: 1470, dtype: object

# %% [markdown]
# ## Tratar con datos nominales y ordinales

# %%
for name in df.columns.to_list():
    print(f'La columna: {name} contiene los elementos {df[name].unique()}')
# Out:
# La columna: Age contiene los elementos [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# La columna: MonthlyIncome contiene los elementos [5993.   nan 2090. ... 9991. 5390. 4404.]
# La columna: Attrition contiene los elementos ['Yes' 'No']
# La columna: BusinessTravel contiene los elementos ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# La columna: DailyRate contiene los elementos [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
# ...

# %%
#def attrition(s):
 #   if s == 'Yes':
  #      return 1
   # else:
    #    return 0
    #
#df_clean['Attrition'] = df_clean['Attrition'].map(attrition)

# %%
# Variables ordinales
Attrition_labels = {'Yes':1,'No':0}
df_clean['Attrition'] = df_clean['Attrition'].map(Attrition_labels)

# %%
df_clean
# Out:
#        Age  MonthlyIncome  Attrition     BusinessTravel  DailyRate  \
# 0     41.0    5993.000000          1      Travel_Rarely     1102.0
# 1     49.0    6505.155419          0  Travel_Frequently      279.0
# 2     37.0    2090.000000          1      Travel_Rarely     1373.0
# 3     33.0    2909.000000          0  Travel_Frequently     1392.0
# 4     27.0    3468.000000          0      Travel_Rarely      591.0
# ...    ...            ...        ...                ...        ...
# 1465  36.0    2571.000000          0  Travel_Frequently      884.0
# 1466  39.0    9991.000000          0      Travel_Rarely      613.0
# 1467  27.0    6142.000000          0      Travel_Rarely      155.0
# 1468  49.0    5390.000000          0  Travel_Frequently     1023.0
# 1469  34.0    4404.000000          0      Travel_Rarely      628.0
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales               1.0        2.0  Life Sciences
# ...

# %%
# Variables nominales
df_clean = pd.get_dummies(df_clean,columns = ['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime'])
df_clean
# Out:
#        Age  MonthlyIncome  Attrition  DailyRate  DistanceFromHome  Education  \
# 0     41.0    5993.000000          1     1102.0               1.0        2.0
# 1     49.0    6505.155419          0      279.0               8.0        1.0
# 2     37.0    2090.000000          1     1373.0               2.0        2.0
# 3     33.0    2909.000000          0     1392.0               3.0        4.0
# 4     27.0    3468.000000          0      591.0               2.0        1.0
# ...    ...            ...        ...        ...               ...        ...
# 1465  36.0    2571.000000          0      884.0              23.0        2.0
# 1466  39.0    9991.000000          0      613.0               6.0        1.0
# 1467  27.0    6142.000000          0      155.0               4.0        3.0
# 1468  49.0    5390.000000          0     1023.0               2.0        3.0
# 1469  34.0    4404.000000          0      628.0               8.0        3.0
#
# ...

# %%
df_clean.describe()
# Out:
#                Age  MonthlyIncome    Attrition    DailyRate  DistanceFromHome  \
# count  1470.000000    1470.000000  1470.000000  1470.000000       1470.000000
# mean     36.923810    6505.155419     0.161224   802.485714          9.192517
# std       9.135373    4706.484668     0.367863   403.509100          8.106864
# min      18.000000    1009.000000     0.000000   102.000000          1.000000
# 25%      30.000000    2914.750000     0.000000   465.000000          2.000000
# 50%      36.000000    4933.000000     0.000000   802.000000          7.000000
# 75%      43.000000    8368.500000     0.000000  1157.000000         14.000000
# max      60.000000   19999.000000     1.000000  1499.000000         29.000000
#
#          Education  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count  1470.000000     1470.000000              1470.000000  1470.000000
# mean      2.912925     1025.556161                 2.721769    65.891156
# ...

# %%
#df_clean.to_csv('Preproced.csv',index=False)

# %% [markdown]
# ## Dtección de valores atípicos

# %% [markdown]
# Este método solo funciona cuando la distribución de los datos es aproximadamente normal

# %%
#%pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
Q1 = df_clean['Age'].quantile(0.25)
Q3 = df_clean['Age'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5*IQR
limite_inferior

limite_superior = Q3 + 1.5*IQR
limite_superior
# Out:
# np.float64(62.5)

# %%
df_clean.boxplot('Age')

# %% [markdown]
# ### Notas. Simulación de datos atípicos

# %%
df_test = df_clean.copy()

indices = np.random.choice(df_test.index,2,replace=False)

df_test.loc[indices[0],'Age'] += 3*IQR
df_test.loc[indices[1],'Age'] += 3*IQR

# %%
df_test.boxplot('Age')
# Out:
# <Axes: >

# %%
# 
Q1 = df_test['Age'].quantile(0.25)
Q3 = df_test['Age'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5*IQR
print(limite_inferior)

limite_superior = Q3 + 1.5*IQR
print(limite_superior)
# Out:
# 10.5
# 62.5

# %%
#plt.hist(df_clean['Age'],bins=30)
sns.distplot(x=df_clean['Age'])
plt.show()
# Out:
# C:\Users\david_zacarias\AppData\Local\Temp\ipykernel_3708\2017028349.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df_clean['Age'])

# %% [markdown]
# # Ejercicio 3

# %% [markdown]
# Tomar 3 variables y determinar si existen datos atípicos

# %%
df_clean
# Out:
#        Age  MonthlyIncome  Attrition  DailyRate  DistanceFromHome  Education  \
# 0     41.0    5993.000000          1     1102.0               1.0        2.0
# 1     49.0    6505.155419          0      279.0               8.0        1.0
# 2     37.0    2090.000000          1     1373.0               2.0        2.0
# 3     33.0    2909.000000          0     1392.0               3.0        4.0
# 4     27.0    3468.000000          0      591.0               2.0        1.0
# ...    ...            ...        ...        ...               ...        ...
# 1465  36.0    2571.000000          0      884.0              23.0        2.0
# 1466  39.0    9991.000000          0      613.0               6.0        1.0
# 1467  27.0    6142.000000          0      155.0               4.0        3.0
# 1468  49.0    5390.000000          0     1023.0               2.0        3.0
# 1469  34.0    4404.000000          0      628.0               8.0        3.0
#
# ...

# %%
Q1 = df_clean['MonthlyIncome'].quantile(0.25)
Q3 = df_clean['MonthlyIncome'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5*IQR
print(limite_inferior)

limite_superior = Q3 + 1.5*IQR
print(limite_superior)
# Out:
# -5265.875
# 16549.125

# %%
df_clean.boxplot('MonthlyIncome')
# Out:
# <Axes: >

# %%
Q1 = df_clean['DistanceFromHome'].quantile(0.25)
Q3 = df_clean['DistanceFromHome'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5*IQR
print(limite_inferior)

limite_superior = Q3 + 1.5*IQR
print(limite_superior)
# Out:
# -16.0
# 32.0

# %%
df_clean.boxplot('DistanceFromHome')
# Out:
# <Axes: >

# %%
Q1 = df_clean['PercentSalaryHike'].quantile(0.25)
Q3 = df_clean['PercentSalaryHike'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5*IQR
print(limite_inferior)

limite_superior = Q3 + 1.5*IQR
print(limite_superior)
# Out:
# 3.0
# 27.0

# %%
df_clean.boxplot('PercentSalaryHike')
# Out:
# <Axes: >

# %%
# Ver las distribuciones de todas las variables
df_clean.hist(bins=30,figsize=(30,30))
plt.show()

# %%
# ITrees, Bosques de aislamiento

# %% [markdown]
# Detección de datos atípicos usando:

# %%
from sklearn.ensemble import IsolationForest

# %%
forest = IsolationForest(contamination=0.05).fit(df_clean[['Age']])

# %%
forest.predict([[80]])
# Out:
# c:\Users\david_zacarias\.conda\envs\CDIA\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# array([-1])

# %% [markdown]
# # Selección de variables de interés

# %%
correlaciones = df_clean.corr()

f,ax = plt.subplots(figsize=(50,50))
sns.heatmap(correlaciones, annot=True)
plt.show()

# %%
sns.pairplot(df_clean,hue='Attrition',vars=['MonthlyIncome','YearsAtCompany'])

# %%
df_clean[['MonthlyIncome','Age']].corr()
# Out:
#                MonthlyIncome      Age
# MonthlyIncome        1.00000  0.49915
# Age                  0.49915  1.00000

# %% [markdown]
# ## Sub dividir dataset
