# %%
import pandas as pd
# Lectura de los datos
df = pd.read_csv('supermarket_sales.csv')
df.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
#
#     Time  Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08  Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29     Cash   76.40                 4.761905        3.8200     9.6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.nunique()
# Out:
# Invoice ID                 1000
# Branch                        3
# City                          3
# Customer type                 2
# Gender                        2
# Product line                  6
# Unit price                  943
# Quantity                     10
# Tax 5%                      990
# Total                       990
# Date                         89
# Time                        506
# Payment                       3
# cogs                        990
# gross margin percentage       1
# gross income                990
# Rating                       61
# dtype: int64

# %%
df.columns.to_list()
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Unit price',
#  'Quantity',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'Payment',
#  'cogs',
#  'gross margin percentage',
#  'gross income',
#  'Rating']

# %%
# Eliminar columnas que no brindan información
valores_unicos_n = df.nunique()

columnas_sin_info = valores_unicos_n[valores_unicos_n==1].index.tolist()
columnas_sin_info
# Out:
# ['gross margin percentage']

# %%
df_clean=df.drop(columnas_sin_info, axis=1)
df_clean.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
#
#     Time  Payment    cogs  gross income  Rating
# 0  13:08  Ewallet  522.83       26.1415     9.1
# 1  10:29     Cash   76.40        3.8200     9.6

# %%
df_clean.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross income      Rating
# count   1000.000000  1000.00000
# mean      15.379369     6.97270
# std       11.708825     1.71858
# min        0.508500     4.00000
# 25%        5.924875     5.50000
# 50%       12.088000     7.00000
# 75%       22.445250     8.50000
# max       49.650000    10.00000

# %% [markdown]
# El conjunto contiene 1000 registros con 17 variables, de las cuales se descartó una 'gross margin percentage', dado que no proporciona información.
#
# De acuerdo con el resumen de las variables, los datos muestran una amplia variabilidad en los precios unitarios, las cantidades vendidas y los totales de las transacciones. La calificación promedio es razonablemente alta, lo que sugiere una satisfacción general positiva. El ingreso bruto es consistente con el impuesto aplicado, reflejando una relación directa

# %%
print(df_clean['City'].unique())
print(df_clean['Customer type'].unique())
print(df_clean['Gender'].unique())
print(df_clean['Product line'].unique())
# Out:
# ['Yangon' 'Naypyitaw' 'Mandalay']
# ['Member' 'Normal']
# ['Female' 'Male']
# ['Health and beauty' 'Electronic accessories' 'Home and lifestyle'
#  'Sports and travel' 'Food and beverages' 'Fashion accessories']

# %%
# Cuando se usa pandas en lugar de utilizar and y or se usan & y |
h_prodline = df_clean[(df_clean['Gender'] == 'Male') & (df_clean['Product line'] == 'Health and beauty')]
h_prodline.head(2)
# Out:
#      Invoice ID Branch      City Customer type Gender       Product line  \
# 3   123-19-1176      A    Yangon        Member   Male  Health and beauty
# 21  371-85-5789      B  Mandalay        Normal   Male  Health and beauty
#
#     Unit price  Quantity  Tax 5%    Total       Date   Time  Payment    cogs  \
# 3        58.22         8  23.288  489.048  1/27/2019  20:33  Ewallet  465.76
# 21       87.98         3  13.197  277.137   3/5/2019  10:40  Ewallet  263.94
#
#     gross income  Rating
# 3         23.288     8.4
# 21        13.197     5.1
